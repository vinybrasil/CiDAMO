# %% [markdown]
# <a href="https://colab.research.google.com/github/vinybrasil/CiDAMO/blob/master/projeto_relmo/customers/CLUSTER_COSSENO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy import cluster
from scipy.cluster.hierarchy import ward, fcluster

plt.rcParams['figure.figsize'] = [20, 15]

import sys
sys.setrecursionlimit(10000)

# %%
data_final = pd.read_csv('/content/drive/My Drive/projeto_relmo/matrix_final_cosseno_nomes_arrumados.csv', index_col=0)
data_final
# Out:
#            0       1           2       3
# 0        1.0    59.0    0.000000     2.0
# 1        2.0  3870.0    0.000000     2.0
# 2     1471.0  3227.0    0.000000     2.0
# 3     3537.0  3899.0    0.000000     3.0
# 4     3547.0  3900.0    0.000000     4.0
# ...      ...     ...         ...     ...
# 3891  7744.0  7787.0   66.723320  3093.0
# 3892  7731.0  7786.0   72.181641   367.0
# 3893  7788.0  7789.0   73.507451  3460.0
# 3894  7763.0  7790.0   98.772148  3661.0
# 3895  7770.0  7791.0  153.578906  3897.0
#
# [3896 rows x 4 columns]

# %%
plt.figure(figsize=(20,15))
x = data_final.to_numpy()
r = dendrogram(x)
#plt.ylim(ymin=-10.0, ymax=2000)
plt.show()
plt.savefig("dendograma_total_cosseno_arrumado.png")

# %%
plt.figure(figsize=(20,15)) #nao ficou mto bom
r = dendrogram(x)
plt.ylim(ymax=20)
plt.axhline(y=11)
plt.show()
plt.savefig("dendograma_20_cosseno_arrumado.png")

# %%
plt.figure(figsize=(20,15))
r = dendrogram(x)
plt.ylim(ymax=10)
plt.axhline(y=6)
plt.show()
plt.savefig("dendograma_10_cosseno_arrumado.png")

# %%
produtos = pd.read_csv("/content/drive/My Drive/projeto_relmo/produtos.csv",index_col=0)

# %%
cutree = cluster.hierarchy.cut_tree(x, height=5)

# %%
len(cutree)
# Out:
# 3897

# %%
#produtos['cluster'] = cutree[:3896]
produtos['cluster'] = cutree[1:3897]

# %%
#nao deu boa rodar no dataset com o nome inteiro. rodar de novo no com o nome arrumado
produtos.to_csv("produtos_clusterizado_cosseno.csv")

# %%
max(cutree)
# Out:
# array([107])

# %%
produtos_arrumado = pd.read_csv('/content/drive/My Drive/projeto_relmo/so_nomes_novos_arrumado.csv',index_col=0)
produtos_arrumado
# Out:
#           arrumadas_novamente_ultima
# 0                       heart holder
# 1                      metal lantern
# 2     cream cupid hearts coat hanger
# 3            union flag water bottle
# 4                              heart
# ...                              ...
# 3891                   letter w ring
# 3892                     letter ring
# 3893               skull phone charm
# 3894                    heart holder
# 3895              paper craft birdie
#
# [3896 rows x 1 columns]

# %%
produtos['produtos_cleaned'] = produtos_arrumado['arrumadas_novamente_ultima']
