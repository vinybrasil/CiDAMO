# %% [markdown]
# <a href="https://colab.research.google.com/github/vinybrasil/CiDAMO/blob/master/projeto_relmo/customers/hierarquico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc

# %%
data = pd.read_csv("/content/drive/My Drive/projeto_relmo/matriz_de_quantidades.csv", index_col=0)

# %%
data
# Out:
#          WHITE HANGING HEART T-LIGHT HOLDER  ...  PAPER CRAFT , LITTLE BIRDIE
# 17850.0                                 122  ...                            0
# 13047.0                                  23  ...                            0
# 12583.0                                   0  ...                            0
# 13748.0                                   0  ...                            0
# 15100.0                                   0  ...                            0
# ...                                     ...  ...                          ...
# 13436.0                                   0  ...                            0
# 15520.0                                   0  ...                            0
# 13298.0                                   0  ...                            0
# 14569.0                                   0  ...                            0
# 12713.0                                   0  ...                            0
#
# [4372 rows x 3896 columns]

# %%
X = data.to_numpy()

# %%
plt.figure(figsize=(200, 140))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(X, method='ward'))
plt.savefig("dendograma.png")
