# %% [markdown]
# <a href="https://colab.research.google.com/github/vinybrasil/CiDAMO/blob/master/projeto_relmo/customers/3_apresentacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/drive/My Drive/projeto_relmo/DATA_SEMNA.csv")

# %%
data
# Out:
#         Unnamed: 0 InvoiceNo StockCode  ... UnitPrice  CustomerID         Country
# 0                0    536365    85123A  ...      2.55     17850.0  United Kingdom
# 1                1    536365     71053  ...      3.39     17850.0  United Kingdom
# 2                2    536365    84406B  ...      2.75     17850.0  United Kingdom
# 3                3    536365    84029G  ...      3.39     17850.0  United Kingdom
# 4                4    536365    84029E  ...      3.39     17850.0  United Kingdom
# ...            ...       ...       ...  ...       ...         ...             ...
# 406824      541904    581587     22613  ...      0.85     12680.0          France
# 406825      541905    581587     22899  ...      2.10     12680.0          France
# 406826      541906    581587     23254  ...      4.15     12680.0          France
# 406827      541907    581587     23255  ...      4.15     12680.0          France
# ...

# %%
data.iloc[406828]
# Out:
# Unnamed: 0                            541908
# InvoiceNo                             581587
# StockCode                              22138
# Description    BAKING SET 9 PIECE RETROSPOT
# Quantity                                   3
# InvoiceDate                  12/9/2011 12:50
# UnitPrice                               4.95
# CustomerID                             12680
# Country                               France
# Name: 406828, dtype: object

# %%
data.iloc[406828].StockCode
# Out:
# '22138'

# %%
#source do algoritmo: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.149.1724&rep=rep1&type=pdf

# %%
#ler customers

print("Lendo customers...\n")
i = 0
customers = []

for item in data['CustomerID'].values:
    if item not in customers:
        customers.append(item)
    i += 1
# Out:
# Lendo customers...

# %%
#ler products

print("Lendo produtos...\n")
i = 0
products = []

for item in data['Description'].values:
    if item not in products:
        products.append(item)
    i += 1
# Out:
# Lendo produtos...

# %%
len(products)
# Out:
# 3896

# %%
novo_df = pd.DataFrame(index=customers, columns=products)
novo_df = novo_df.fillna(0)
novo_df
# Out:
#          WHITE HANGING HEART T-LIGHT HOLDER  ...  PAPER CRAFT , LITTLE BIRDIE
# 17850.0                                   0  ...                            0
# 13047.0                                   0  ...                            0
# 12583.0                                   0  ...                            0
# 13748.0                                   0  ...                            0
# 15100.0                                   0  ...                            0
# ...                                     ...  ...                          ...
# 13436.0                                   0  ...                            0
# 15520.0                                   0  ...                            0
# 13298.0                                   0  ...                            0
# 14569.0                                   0  ...                            0
# 12713.0                                   0  ...                            0
#
# [4372 rows x 3896 columns]

# %%
'''z = 0
while z < len(data_semna):
    #print('Lendo ', z, ' de ', len(data_semna) - 1, ' registros.')
    cliente = data_semna['CustomerID'][z]
    
    produto = data_semna['Description'][z]
    quantidade = data_semna['Quantity'][z]
    #print(quantidade)
    cluster = cluster_output[cluster_output['produtos'] == produto]['cluster'].values
    if len(cluster) == 1:
        cluster_id = sum(cluster)
        if (novo_df[cluster_id][cliente] == 0):
        #novo_df[cluster_id][cliente] += quantidade
            novo_df[cluster_id][cliente] += 1
        else:
            pass
    else:
        print("algo deu ruim")
    z += 1
novo_df'''

z = 0
while z < len(data):
    #print('Lendo ', z, ' de ', len(data_semna) - 1, ' registros.')
    cliente = data['CustomerID'][z]
    
    produto = data['Description'][z]
    quantidade = data['Quantity'][z]
    #print(quantidade)
    #cluster = cluster_output[cluster_output['produtos'] == produto]['cluster'].values
    '''if len(cluster) == 1:
        cluster_id = sum(cluster)
        if (novo_df[cluster_id][cliente] == 0):
        #novo_df[cluster_id][cliente] += quantidade
            novo_df[cluster_id][cliente] += 1
        else:
            pass
    else:
        print("algo deu ruim")'''
    
    if (novo_df[produto][cliente] == 0):
        #novo_df[cluster_id][cliente] += quantidade
            novo_df[produto][cliente] += 1
    else:
          pass
    z += 1
novo_df
# Out:
#          WHITE HANGING HEART T-LIGHT HOLDER  ...  PAPER CRAFT , LITTLE BIRDIE
# 17850.0                                   1  ...                            0
# 13047.0                                   1  ...                            0
# 12583.0                                   0  ...                            0
# 13748.0                                   0  ...                            0
# 15100.0                                   0  ...                            0
# ...                                     ...  ...                          ...
# 13436.0                                   0  ...                            0
# 15520.0                                   0  ...                            0
# 13298.0                                   0  ...                            0
# 14569.0                                   0  ...                            0
# 12713.0                                   0  ...                            0
#
# [4372 rows x 3896 columns]

# %%
novo_df.sample(20)
# Out:
#          WHITE HANGING HEART T-LIGHT HOLDER  ...  PAPER CRAFT , LITTLE BIRDIE
# 13285.0                                   0  ...                            0
# 13614.0                                   0  ...                            0
# 14427.0                                   0  ...                            0
# 17095.0                                   0  ...                            0
# 17190.0                                   0  ...                            0
# 14067.0                                   1  ...                            0
# 16115.0                                   0  ...                            0
# 15335.0                                   0  ...                            0
# 17841.0                                   1  ...                            0
# 13273.0                                   0  ...                            0
# 13349.0                                   0  ...                            0
# ...

# %%
max(novo_df)
# Out:
# 'ZINC WIRE SWEETHEART LETTER TRAY'

# %%
#fazer a matriz dos recibos

#ler products

print("Lendo recibos...\n")
i = 0
recibos = []

for item in data['InvoiceNo'].values:
    if item not in recibos:
        recibos.append(item)
    i += 1
# Out:
# Lendo recibos...

# %%
df_recibos = pd.DataFrame(index=recibos, columns=products)
df_recibos = df_recibos.fillna(0)
df_recibos
# Out:
#         WHITE HANGING HEART T-LIGHT HOLDER  ...  PAPER CRAFT , LITTLE BIRDIE
# 536365                                   0  ...                            0
# 536366                                   0  ...                            0
# 536367                                   0  ...                            0
# 536368                                   0  ...                            0
# 536369                                   0  ...                            0
# ...                                    ...  ...                          ...
# 581583                                   0  ...                            0
# 581584                                   0  ...                            0
# 581585                                   0  ...                            0
# 581586                                   0  ...                            0
# 581587                                   0  ...                            0
#
# [22190 rows x 3896 columns]

# %%
len(df_recibos)
# Out:
# 22190

# %%
clientes_recibos = []
for item in recibos:
  #cluster = cluster_output[cluster_output['produtos'] == produto]['cluster'].values
  cliente = data[data['InvoiceNo'] == item]['CustomerID'].values
  clientes_recibos.append(cliente[0])

# %%
len(clientes_recibos)
# Out:
# 22190

# %%
df_cliente_recibos = pd.DataFrame(index = recibos,data=clientes_recibos)

# %%
df_cliente_recibos.sample(20)
# Out:
#                0
# 573331   15860.0
# 580151   17811.0
# 564351   13881.0
# 571740   17973.0
# 556479   16983.0
# 549593   18008.0
# 561650   15329.0
# 552472   16503.0
# 567328   14356.0
# C555355  15841.0
# 537469   17720.0
# C580707  12957.0
# 580669   15159.0
# 569099   17961.0
# 577606   12462.0
# 579433   17466.0
# 572184   12403.0
# 563438   13743.0
# 558462   13982.0
# 575352   12504.0

# %%
df_cliente_recibos[0].value_counts()
# Out:
# 14911.0    248
# 12748.0    224
# 17841.0    169
# 14606.0    128
# 13089.0    118
#           ...
# 13889.0      1
# 16272.0      1
# 14729.0      1
# 16123.0      1
# 17925.0      1
# Name: 0, Length: 4372, dtype: int64

# %%
df_cliente_recibos[0].value_counts().mean()
# Out:
# 5.07548032936871

# %%
np.std(df_cliente_recibos[0].value_counts().values)
# Out:
# 9.337686083950539

# %%
import matplotlib.pyplot as plt

# %%
df_cliente_recibos[0].value_counts().plot(kind='pie')

# %%
plt.scatter(np.arange(0,len(df_cliente_recibos[0].value_counts()),1), df_cliente_recibos[0].value_counts().values)

# %%
#criar um df com ticket medio
#ticket médio: soma do que gastou/numero de recibos

total_gasto = []
for item in recibos:
  #cluster = cluster_output[cluster_output['produtos'] == produto]['cluster'].values
  preco = data[data['InvoiceNo'] == item]['UnitPrice'].values
  quantidade = data[data['InvoiceNo'] == item]['Quantity'].values
  #print(preco)
  #print(quantidade)
  gasto = np.dot(preco, quantidade)
  #print(gasto)
  total_gasto.append(gasto)
len(total_gasto)
# Out:
# 22190

# %%
clientes_recibos
# Out:
# [17850.0,
#  17850.0,
#  13047.0,
#  13047.0,
#  13047.0,
#  12583.0,
#  13748.0,
#  17850.0,
#  17850.0,
#  15100.0,
#  17850.0,
#  15291.0,
#  17850.0,
#  14688.0,
#  17809.0,
#  15311.0,
#  14527.0,
#  16098.0,
#  15311.0,
#  18074.0,
#  17420.0,
#  16029.0,
#  16029.0,
#  16250.0,
#  12431.0,
#  17511.0,
#  17548.0,
#  13705.0,
#  13747.0,
#  13408.0,
#  13767.0,
#  17850.0,
#  17924.0,
#  13448.0,
#  17850.0,
#  13448.0,
#  15862.0,
#  15513.0,
#  12791.0,
#  16218.0,
#  14045.0,
#  17850.0,
#  17850.0,
#  14307.0,
#  17908.0,
#  17920.0,
#  12838.0,
#  13255.0,
#  16583.0,
#  18085.0,
#  13758.0,
#  13694.0,
#  15983.0,
#  14849.0,
#  14849.0,
#  17968.0,
#  14849.0,
#  16210.0,
#  17897.0,
#  17377.0,
#  16552.0,
#  17181.0,
#  17897.0,
#  17951.0,
#  14729.0,
#  12748.0,
#  15012.0,
#  12868.0,
#  17572.0,
#  14078.0,
#  14001.0,
#  12662.0,
#  15525.0,
#  14237.0,
#  17905.0,
#  15485.0,
#  12433.0,
#  16955.0,
#  15350.0,
#  15605.0,
#  18144.0,
#  15922.0,
#  14594.0,
# ...

# %%
df_cliente_recibos_total = pd.DataFrame(index = recibos,data=(clientes_recibos))

# %%
df_cliente_recibos_total['gasto'] = total_gasto

# %%
df_cliente_recibos_total.columns = ['cliente', 'gasto_neste_recibo']

# %%
df_cliente_recibos_total.to_csv("/content/drive/My Drive/projeto_relmo/df_cliente_recibos_total.csv")

# %%
df_cliente_recibos_total
# Out:
#         cliente  gasto_neste_recibo
# 536365  17850.0              139.12
# 536366  17850.0               22.20
# 536367  13047.0              278.73
# 536368  13047.0               70.05
# 536369  13047.0               17.85
# ...         ...                 ...
# 581583  13777.0              124.60
# 581584  13777.0              140.64
# 581585  15804.0              329.05
# 581586  13113.0              339.20
# 581587  12680.0              249.45
#
# [22190 rows x 2 columns]

# %%
df_cliente_recibos_total.sample(15)
# Out:
#          cliente  gasto_neste_recibo
# 546832   13216.0              333.74
# 575194   16767.0              359.46
# C561589  16133.0              -12.60
# 543799   17236.0              119.76
# 544968   13458.0              676.92
# 551384   15223.0              454.90
# 541732   16387.0               94.36
# C561628  16422.0               -9.60
# 561883   13388.0               55.80
# 543376   16321.0               67.95
# 574555   16426.0              221.63
# 547508   12683.0              378.00
# 562549   17092.0              498.17
# 550333   15410.0              456.20
# 540980   14514.0              255.25

# %%
df_cliente_recibos_total.min()
# Out:
# cliente                12346.0
# gasto_neste_recibo   -168469.6
# dtype: float64

# %%
plt.plot(np.arange(0, len(df_cliente_recibos_total['gasto_neste_recibo'])), df_cliente_recibos_total['gasto_neste_recibo'].values, 'o', color='black',markersize=2.5)
plt.grid(True)

# %%
#pegar o valor de cada recibo, somar e dividir pelo número de; Esse é o gasto médio


z = 0
while z < len(df_cliente_recibos_total):
    #print('Lendo ', z, ' de ', len(data_semna) - 1, ' registros.')
    cliente = df_cliente_recibos_total['CustomerID'][z]
    
    produto = data['Description'][z]
    quantidade = data['Quantity'][z]
    #print(quantidade)
    #cluster = cluster_output[cluster_output['produtos'] == produto]['cluster'].values
    '''if len(cluster) == 1:
        cluster_id = sum(cluster)
        if (novo_df[cluster_id][cliente] == 0):
        #novo_df[cluster_id][cliente] += quantidade
            novo_df[cluster_id][cliente] += 1
        else:
            pass
    else:
        print("algo deu ruim")'''
    
    if (novo_df[produto][cliente] == 0):
        #novo_df[cluster_id][cliente] += quantidade
            novo_df[produto][cliente] += 1
    else:
          pass
    z += 1
novo_df
